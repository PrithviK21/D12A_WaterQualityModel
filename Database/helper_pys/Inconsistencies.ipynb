# %%
import pandas as pd
import numpy as np
import missingno as msno

# %%
df = pd.read_excel("Water_Quality_Only_Rivers_noNulls_morethan3stations.xlsx")

# %%
df
# Out:
#       STATION CODE                                           LOCATION  \
# 0                1                   SABARMATI AT DHAROI DAM, GUJARAT
# 1                1                   SABARMATI AT DHAROI DAM, GUJARAT
# 2                1                   SABARMATI AT DHAROI DAM, GUJARAT
# 3                1                   SABARMATI AT DHAROI DAM, GUJARAT
# 4                1                   SABARMATI AT DHAROI DAM, GUJARAT
# ...            ...                                                ...
# 9347         10157        RIVER GANGA AT BATHING GHAT (JAJMAU BRIDGE)
# 9348         10157        RIVER GANGA AT BATHING GHAT (JAJMAU BRIDGE)
# 9349         10162  ARRAH-CHHAPRA ROAD BRIDGE (KOILWER BANURA- CHH...
# 9350         10162  ARRAH-CHHAPRA ROAD BRIDGE (KOILWER BANURA- CHH...
# 9351         10162  ARRAH-CHHAPRA ROAD BRIDGE (KOILWER BANURA- CHH...
#
#           RIVER          STATE  TEMPERATURE  DISSOLVED OXYGEN    PH  \
# ...

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
for i in df.columns:
    print("For "+ i + " "+ str(df[i].max()))
# Out:
# For STATION CODE 10162
# For LOCATION ZUARI AT PANCHAWADI
# For RIVER ZUARI
# For STATE WEST BENGAL
# For TEMPERATURE 102.0
# For DISSOLVED OXYGEN 85.0
# For PH 1103.0
# For CONDUCTIVITY 256690.0
# For BOD 577.5
# For NITRATE 442.35
# For TOTAL COLIFORM 2475240000.0
# For YEAR 2019

# %%
dfmix = pd.read_excel("uh.xlsx")
dfmix
# Out:
#       STATION CODE                                           LOCATION  \
# 0             1001                           BEAS AT U/S MANALI, H.P.
# 1             1002                             BEAS AT D/S KULU, H.P.
# 2             1003                              BEAS AT D/S AUT, H.P.
# 3             1004                       BEAS AT U/S PANDON DAM, H.P.
# 4             1005     BEAS AT EXIT OF TUNNEL DEHAL POWER HOUSE, H.P.
# ...            ...                                                ...
# 9935          2387               SUBARNAREKHA AT GHATISLA ROAD BRIDGE
# 9936          2395                          SUBARNAREKHA AT HATIA DAM
# 9937          2397                       SUBARNAREKHA AT GATALSUD DAM
# 9938          2399                        SUBARNAREKHA AT CHANDIL DAM
# 9939          1641  SUBARNAREKHA AT RAJGHAT NEAR JHARKHAND BORDER,...
#
#              RIVER             STATE  TEMPERATURE MIN  TEMPERATURE MAX  \
# ...

# %%
for i in df.index:
    if df['PH'][i] > 14:
        stat_code = df['STATION CODE'][i]
        df['PH'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['PH MIN'].mean()
    if df['TEMPERATURE'][i] > 45:
        stat_code = df['STATION CODE'][i]
        df['TEMPERATURE'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['TEMPERATURE MIN'].mean()
    if df['CONDUCTIVITY'][i] > 1500:
        stat_code = df['STATION CODE'][i]
        df['CONDUCTIVITY'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['CONDUCTIVITY MIN'].mean()
    if df['DISSOLVED OXYGEN'][i] > 3:
        stat_code = df['STATION CODE'][i]
        df['DISSOLVED OXYGEN'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['DISSOLVED OXYGEN MIN'].mean()
    if df['BOD'][i] > 30:
        stat_code = df['STATION CODE'][i]
        df['BOD'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['BOD MIN'].mean()
    if df['NITRATE'][i] > 10:
        stat_code = df['STATION CODE'][i]
        df['NITRATE'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['NITRATE MIN'].mean()
    if df['TOTAL COLIFORM'][i] > 30000:
        stat_code = df['STATION CODE'][i]
        df['TOTAL COLIFORM'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['TOTAL COLIFORM MIN'].mean()
        
df.to_excel("Inconsistencies.xlsx")
# Out:
# C:\Users\SHUBHA~1\AppData\Local\Temp/ipykernel_24120/2401488306.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DISSOLVED OXYGEN'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['DISSOLVED OXYGEN MIN'].mean()
# C:\Users\SHUBHA~1\AppData\Local\Temp/ipykernel_24120/2401488306.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CONDUCTIVITY'][i] = '%.2f' % dfmix[dfmix['STATION CODE'] == stat_code]['CONDUCTIVITY MIN'].mean()
# C:\Users\SHUBHA~1\AppData\Local\Temp/ipykernel_24120/2401488306.py:16: SettingWithCopyWarning:
# ...

# %%
for i in df.columns:
    print("For "+ i + " "+ str(df[i].max()))
# Out:
# For STATION CODE 10162
# For LOCATION ZUARI AT PANCHAWADI
# For RIVER ZUARI
# For STATE WEST BENGAL
# For TEMPERATURE 37.5
# For DISSOLVED OXYGEN 13.19
# For PH 1065.0
# For CONDUCTIVITY 34668.33
# For BOD 70.55
# For NITRATE 11.37
# For TOTAL COLIFORM 118408000.0
# For YEAR 2019

# %%
df[df['CONDUCTIVITY'] > 1500].shape
# Out:
# (90, 12)

# %%
df[df['TOTAL COLIFORM'] > 30000].shape
# Out:
# (427, 12)

# %%
df[df['PH'] > 14].shape
# Out:
# (8, 12)
