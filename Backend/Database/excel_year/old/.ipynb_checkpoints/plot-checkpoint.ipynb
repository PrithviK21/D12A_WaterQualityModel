# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# %%
df = pd.read_excel("Dataset_with_stations_greaterthan_5.xlsx")
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
df3 = df[['STATION CODE', 'YEAR', 'TOTAL COLIFORM']].copy()
df3.loc[df['TOTAL COLIFORM'] > 1000000, 'TOTAL COLIFORM'] %= 1000000
df3.sort_values('TOTAL COLIFORM')
# Out:
#       STATION CODE  YEAR  TOTAL COLIFORM
# 2103          1265  2019             0.0
# 6867          3023  2012             0.0
# 3744          1853  2019             0.0
# 3735          1852  2019             0.0
# 3727          1851  2019             0.0
# ...            ...   ...             ...
# 6858          3022  2012        920648.0
# 2542          1325  2014        939974.0
# 3093          1470  2013        942941.0
# 1100          1121  2010        945083.0
# 2485          1320  2014        991748.0
#
# [7117 rows x 3 columns]

# %%
# from sklearn.preprocessing import MinMaxScaler
# df3['TOTAL COLIFORM MINMAX'] = MinMaxScaler().fit_transform(df2[['TOTAL COLIFORM']])
# df3

# %%
fig = px.bar(df3, y='TOTAL COLIFORM', facet_col='YEAR', facet_col_wrap=3, template = 'plotly_white')
fig
# Out:
# <div>                            <div id="a70cc75c-a18a-4874-b425-57199a1600ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a70cc75c-a18a-4874-b425-57199a1600ec")) {                    Plotly.newPlot(                        "a70cc75c-a18a-4874-b425-57199a1600ec",                        [{"alignmentgroup":"True","hovertemplate":"YEAR=2008<br>index=%{x}<br>TOTAL COLIFORM=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":[0,5,14,21,26,35,44,55,67,78,90,95,100,105,110,122,133,145,157,168,180,192,203,212,220,231,241,246,255,262,270,277,288,370,380,391,441,449,459,470,482,494,506,511,516,525,537,549,560,570,582
# ...

# %%
dfscale = df.copy()
dfscale.loc[df['TOTAL COLIFORM'] > 1000000, 'TOTAL COLIFORM'] %= 1000000
dfscale.sort_values('TOTAL COLIFORM')
dfscale.to_excel("mod10e6.xlsx", index=False)
