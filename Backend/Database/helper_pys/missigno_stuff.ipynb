# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_excel("Water_Quality_Only_Rivers_means_nospaces.xlsx")
df.head()
# Out:
#    STATION CODE                                 LOCATION     RIVER  \
# 0          1478  KALINADI AT D/S OF MUZAFFAR NAGAR, U.P.  KALINADI
# 1          1497                  YAMUNA AT MAZAWALI, U.P    YAMUNA
# 2          1497                  YAMUNA AT MAZAWALI, U.P    YAMUNA
# 3          1123                       YAMUNA U/S MATHURA    YAMUNA
# 4          1125                          YAMUNA U/S AGRA    YAMUNA
#
#             STATE  TEMPERATURE  DISSOLVED OXYGEN    PH  CONDUCTIVITY    BOD  \
# 0  UTTAR\nPRADESH          0.0              0.00  7.10         931.0  77.50
# 1   UTTAR PRADESH          0.0              1.50  7.80        2303.0  31.50
# 2  UTTAR\nPRADESH          0.0              2.95  7.35        1198.0  25.55
# 3   UTTAR PRADESH          0.0              3.60  7.85        2170.0  14.50
# 4  UTTAR\nPRADESH          0.0              4.25  7.50        1197.0   9.75
#
#    NITRATE  TOTAL COLIFORM  YEAR
# 0    0.600       9400000.0  2019
# 1    0.565       4605500.0  2017
# ...

# %%
df.isna().sum()
# Out:
# STATION CODE          0
# LOCATION              0
# RIVER                 0
# STATE                 0
# TEMPERATURE         199
# DISSOLVED OXYGEN    157
# PH                   56
# CONDUCTIVITY        368
# BOD                 196
# NITRATE             968
# TOTAL COLIFORM      924
# YEAR                  0
# dtype: int64

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
gdf = pd.read_excel("groupby_interpolated.xlsx")
gdf.head()
# Out:
#    STATION CODE                          LOCATION      RIVER    STATE  \
# 0             1  SABARMATI AT DHAROI DAM, GUJARAT  SABARMATI  GUJARAT
# 1             1  SABARMATI AT DHAROI DAM, GUJARAT  SABARMATI  GUJARAT
# 2             1  SABARMATI AT DHAROI DAM, GUJARAT  SABARMATI  GUJARAT
# 3             1  SABARMATI AT DHAROI DAM, GUJARAT  SABARMATI  GUJARAT
# 4             1  SABARMATI AT DHAROI DAM, GUJARAT  SABARMATI  GUJARAT
#
#    TEMPERATURE  DISSOLVED OXYGEN    PH  CONDUCTIVITY    BOD  NITRATE  \
# 0        28.00              8.20  8.40         593.0   3.00    0.300
# 1        30.00              6.77  8.30        1693.5  38.60    1.950
# 2        28.00              7.20  7.78         343.5   1.95    0.074
# 3        27.75              7.40  8.05         466.0   1.55    0.395
# 4        27.50              7.60  7.25         452.0   0.85    0.200
#
#    TOTAL COLIFORM  YEAR
# 0            15.0  2008
# 1           110.0  2016
# 2            20.0  2017
# 3            12.5  2018
# ...

# %%
gdf.isna().sum()
# Out:
# STATION CODE          0
# LOCATION              0
# RIVER                 0
# STATE                 0
# TEMPERATURE          48
# DISSOLVED OXYGEN     65
# PH                    0
# CONDUCTIVITY        160
# BOD                  40
# NITRATE             475
# TOTAL COLIFORM      583
# YEAR                  0
# dtype: int64

# %%
msno.matrix(gdf)
# Out:
# <AxesSubplot:>
